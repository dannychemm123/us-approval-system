# %%
print("okay")
# Out:
# okay

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://contidan:contidan@cluster0.zgimvij.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# %%
import pandas as pd
from db_connect.mongo_crud import MongoDBOperation
df = pd.read_csv("EasyVisa.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.shape
# Out:
# (25480, 12)

# %%
mongodb_uri = "mongodb+srv://contidan:contidan@cluster0.zgimvij.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
mongodb_name = "US_VISA"
collection_name = "us_visa_data"

# %%
mongo = MongoDBOperation(mongodb_uri,mongodb_name,collection_name)

# %%
#mongo.bulk_insert("EasyVisa.csv",collection_name)

# %%
record = mongo.find({"case_id":"EZYV15"})
record
# Out:
# [{'_id': ObjectId('668ad401f8d54c2de49c7c92'),
#   'case_id': 'EZYV15',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 15756,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'South',
#   'prevailing_wage': 220081.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'}]

# %%
records = mongo.find()

# %%
for i, j in enumerate(records[:10]):  #
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('668ad401f8d54c2de49c7c84'), 'case_id': 'EZYV01', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 14513, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 592.2029, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 1: {'_id': ObjectId('668ad401f8d54c2de49c7c85'), 'case_id': 'EZYV02', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2412, 'yr_of_estab': 2002, 'region_of_employment': 'Northeast', 'prevailing_wage': 83425.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# ...

# %%
data = pd.DataFrame(list(records))
data.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  668ad401f8d54c2de49c7c84  EZYV01      Asia           High School
# 1  668ad401f8d54c2de49c7c85  EZYV02      Asia              Master's
# 2  668ad401f8d54c2de49c7c86  EZYV03      Asia            Bachelor's
# 3  668ad401f8d54c2de49c7c87  EZYV04      Asia            Bachelor's
# 4  668ad401f8d54c2de49c7c88  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if "_id" in data.columns.to_list():
    data = data.drop(columns=["_id"],axis=1)

# %%
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...
